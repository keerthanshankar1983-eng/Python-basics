# %% [markdown]
# <a href="https://colab.research.google.com/github/keerthanshankar1983-eng/Python-basics/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Age = int(input("enter your age:"))

if Age>=18:
   print("you can vote")

else:
   print("come again next year")
# Out:
# enter your age:20
# you can vote

# %%
marks = int(input("Enter student marks: "))

if marks < 50:
    marks = marks + 10
    print("Grace marks added.")
    print("Updated Marks:", marks)
else:
    print("Pass")
# Out:
# Enter student marks: 40
# Grace marks added.
# Updated Marks: 50
